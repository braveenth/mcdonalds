# %% [markdown]
# # <center> Exploring McDonald's Undocumented API
# ## <center>Braveenth Rasanayagam

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <h2> Table of Contents</h2>
# <font size = 3>
# 1. <a href="#item1">Download and Explore Data</a>
# 2. <a href="#item2">Visualizations</a>
#
# </font>
# <br>
# <p></p>
#
# </div>

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import numpy as np # library to handle data
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

print 'Libraries imported.'
# Out:
# Libraries imported.

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# ## 1. Download and Explore Data

# %% [markdown]
# #### Define the corresponding URL

# %%
# Use URL obtained from Charles(proxy)
url = "https://www.mcdonalds.com/wws/json/getItemDetails.htm?country=CA&language=en&showLiveData=true&item=200139"

# To-do: insert .format and allow for variables

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
# Use URL obtained from Charles(proxy)
url = "https://www.mcdonalds.com/wws/json/getItemDetails.htm?country=CA&language=en&showLiveData=true&item=200139"

results = requests.get(url).json()
results
# Out:
# {u'item': {u'allergens': {},
#   u'attach_item_hero_image': {u'alt_text': {},
#    u'description': {},
#    u'image_name': u'en/mcdonalds-big-mac-hero.jpg',
#    u'url': u'en/mcdonalds-big-mac-hero.jpg'},
#   u'attach_item_thumbnail_image': {u'alt_text': {},
#    u'description': {},
#    u'image_name': u'en/mcdonalds-big-mac.jpg',
#    u'url': u'en/mcdonalds-big-mac.jpg'},
#   u'attach_quality_statement_image': {u'alt_text': {},
#    u'description': {},
#    u'image_name': u't_Big_Mac_sandwich.png',
#    u'url': u't_Big_Mac_sandwich.png'},
#   u'attach_transparent_icon_image': {u'alt_text': {},
#    u'description': {},
#    u'image_name': u'en/mcdonalds-big-mac.png',
#    u'url': u'en/mcdonalds-big-mac.png'},
#   u'categories': {u'category': {u'id': 100005, u'name': u'Beef'}},
#   u'color': {},
#   u'color_picker': {},
#   u'components': {u'component': [{u'display_order': 1,
#      u'external_id': 300118,
#      u'id': 300118,
#      u'import_id': u'WRIN 00063-000',
# ...

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to items
items = results['item']

# tranform venues into a dataframe
dataframe = json_normalize(items)

# display first five rows of dataframe
dataframe.head()
# Out:
#   attach_item_hero_image.image_name     attach_item_hero_image.url  \
# 0     en/mcdonalds-big-mac-hero.jpg  en/mcdonalds-big-mac-hero.jpg
#
#   attach_item_thumbnail_image.image_name attach_item_thumbnail_image.url  \
# 0               en/mcdonalds-big-mac.jpg        en/mcdonalds-big-mac.jpg
#
#   attach_quality_statement_image.image_name  \
# 0                    t_Big_Mac_sandwich.png
#
#   attach_quality_statement_image.url attach_transparent_icon_image.image_name  \
# 0             t_Big_Mac_sandwich.png                 en/mcdonalds-big-mac.png
#
#   attach_transparent_icon_image.url  categories.category.id  \
# 0          en/mcdonalds-big-mac.png                  100005
#
#   categories.category.name                               components.component  \
# 0                     Beef  [{u'import_id': u'WRIN 00063-000', u'product_t...
#
#    default_category.category.id default_category.category.name  \
# 0                        100005                           Beef
#
# ...
